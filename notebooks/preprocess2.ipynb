# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/noahjadallah/Documents/Uni/UB/Final Project/datasets/cord/metadata.csv')
# Out:
# /var/folders/6v/1hlsbcg507xgz0h6dn6dpz6m0000gn/T/ipykernel_33789/3795559761.py:1: DtypeWarning: Columns (1,4,5,6,13,14,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/noahjadallah/Documents/Uni/UB/Final Project/datasets/cord/metadata.csv')

# %%
df
# Out:
#         cord_uid                                       sha  \
# 0       ug7v899j  d1aafb70c066a2068b02786f8929fd9c900897fb
# 1       02tnwd4m  6b0567729c2143a66d737eb0a2f63f2dce2e5a7d
# 2       ejv2xln0  06ced00a5fc04215949aa72528f2eeaae1d58927
# 3       2b73a28n  348055649b6b8cf2b9a376498df9bf41f7123605
# 4       9785vg6d  5f48792a5fa08bed9f56016f4981ae2ca6031b32
# ...          ...                                       ...
# 192504  z4ro6lmh  203f36475be74229101548475d68352b939f8b5b
# 192505  hi8k8wvb  9f1bc99798e8823e690697394dcb23533a45c60e
# 192506  ma3ndg41  ffba777376718ef2a0dd74a8eab90e2bfacd240f
# 192507  wh10285j  d521c5a2dcbd79a5be606fcf586b1e0448344172
# 192508  pnl9th2c  c047bf76813106d4fd586e49164e7feddfbe352f
#
#                       source_x  \
# 0                          PMC
# 1                          PMC
# 2                          PMC
# 3                          PMC
# 4                          PMC
# ...                        ...
# ...

# %%
def get_metadata(doc_id):
    doc = df.loc[df['cord_uid'] == doc_id]
    return doc[['cord_uid', 'title', 'doi', 'source_x', 'abstract', 'publish_time', 'authors', 'url']].iloc[0].to_dict()

# %%
get_metadata('wh10285j')
# Out:
# {'cord_uid': 'wh10285j',
#  'title': "Nimble, Together: A Training Program's Response to the COVID-19 Pandemic",
#  'doi': '10.1097/sla.0000000000003994',
#  'source_x': 'Medline; PMC',
#  'abstract': nan,
#  'publish_time': '2020-04-29',
#  'authors': 'Bryan, Darren S.; Benjamin, Andrew J.; Schneider, Andrew B.; Milner, Ross; Matthews, Jeffrey B.; Roggin, Kevin K.',
#  'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32355117/; https://doi.org/10.1097/sla.0000000000003994'}

# %%
df.columns
# Out:
# Index(['cord_uid', 'sha', 'source_x', 'title', 'doi', 'pmcid', 'pubmed_id',
#        'license', 'abstract', 'publish_time', 'authors', 'journal', 'mag_id',
#        'who_covidence_id', 'arxiv_id', 'pdf_json_files', 'pmc_json_files',
#        'url', 's2_id'],
#       dtype='object')
